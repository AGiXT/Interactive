# %%
import logging
from FrontEnd import TestRunner

logging.basicConfig(
    level=logging.INFO, format="%(asctime)s - %(levelname)s - %(message)s"
)

if __name__ == "__main__":
    TestRunner().run()
# Out:
# Linux Detected, using asyncio.run
# 2025-06-08 22:46:42,558 - INFO - Navigating to http://localhost:3437
# CONSOLE MESSAGE: %cDownload the React DevTools for a better development experience: https://reactjs.org/link/react-devtools
# CONSOLE MESSAGE: font-weight:bold
# 2025-06-08 22:46:44,993 - INFO - [20250608_224644] Action: The landing page of the application is the first thing the user sees. - Screenshot path: test_screenshots/test_run_20250608_224641/20250608_224644_The_landing_page_of_the_application_is_the_first_thing_the_user_sees_.png
# 2025-06-08 22:46:44,994 - INFO - Screenshotting page at http://localhost:3437/
# 2025-06-08 22:46:47,082 - INFO - Clicking 'Register or Login' button
# 2025-06-08 22:46:47,133 - INFO - [20250608_224647] Action: The user has multiple authentication options if enabled, including several o auth options such as Microsoft or Google. For this test, we will use the basic email authentication. - Screenshot path: test_screenshots/test_run_20250608_224641/20250608_224647_The_user_has_multiple_authentication_options_if_enabled__including_several_o_auth_options_such_as_Microsoft_or_Google__For_this_test__we_will_use_the_basic_email_authentication_.png
# 2025-06-08 22:46:47,133 - INFO - Screenshotting page at http://localhost:3437/
# 2025-06-08 22:46:49,203 - INFO - The user enters their email address in the registration form. Since this e-mail address doesn't have an account yet, we proceed to the registration page.
# 2025-06-08 22:46:59,239 - INFO - [20250608_224659] Action: The user enters their email address in the registration form. Since this e-mail address doesn't have an account yet, we proceed to the registration page. - Screenshot path: test_screenshots/test_run_20250608_224641/20250608_224659_The_user_enters_their_email_address_in_the_registration_form__Since_this_e-mail_address_doesn_t_have_an_account_yet__we_proceed_to_the_registration_page_.png
# 2025-06-08 22:46:59,240 - INFO - Screenshotting page at http://localhost:3437/user
# 2025-06-08 22:47:01,302 - INFO - Clicking the 'Continue with Email' button advances the process.
# 2025-06-08 22:47:11,360 - INFO - [20250608_224711] Action: Clicking the 'Continue with Email' button advances the process. - Screenshot path: test_screenshots/test_run_20250608_224641/20250608_224711_Clicking_the__Continue_with_Email__button_advances_the_process_.png
# 2025-06-08 22:47:11,360 - INFO - Screenshotting page at http://localhost:3437/user/register
# 2025-06-08 22:47:13,433 - INFO - The user enters their first name, in this case. Test. We are using the name Test User for demonstration purposes.
# 2025-06-08 22:47:23,459 - INFO - [20250608_224723] Action: The user enters their first name, in this case. Test. We are using the name Test User for demonstration purposes. - Screenshot path: test_screenshots/test_run_20250608_224641/20250608_224723_The_user_enters_their_first_name__in_this_case__Test__We_are_using_the_name_Test_User_for_demonstration_purposes_.png
# 2025-06-08 22:47:23,459 - INFO - Screenshotting page at http://localhost:3437/user/register
# 2025-06-08 22:47:25,551 - INFO - The user enters their last name: User.
# 2025-06-08 22:47:35,582 - INFO - [20250608_224735] Action: The user enters their last name: User. - Screenshot path: test_screenshots/test_run_20250608_224641/20250608_224735_The_user_enters_their_last_name__User_.png
# 2025-06-08 22:47:35,582 - INFO - Screenshotting page at http://localhost:3437/user/register
# 2025-06-08 22:47:37,650 - INFO - Clicking the 'Register' button advances the login process to the multifactor authentication confirmation step after registration, ensuring the user has enrolled therein.
# 2025-06-08 22:47:47,694 - INFO - [20250608_224747] Action: Clicking the 'Register' button advances the login process to the multifactor authentication confirmation step after registration, ensuring the user has enrolled therein. - Screenshot path: test_screenshots/test_run_20250608_224641/20250608_224747_Clicking_the__Register__button_advances_the_login_process_to_the_multifactor_authentication_confirmation_step_after_registration__ensuring_the_user_has_enrolled_therein_.png
# 2025-06-08 22:47:47,694 - INFO - Screenshotting page at http://localhost:3437/user/login?otp_uri=otpauth://totp/AGiXT:a649b32c-ba39-4575-b429-7490e8585bca%40example.com?secret=IIULMPUJZI2WJAASLM2N5UNIB3F7FZ5E&issuer=AGiXT
# 2025-06-08 22:47:49,767 - INFO - After successfully entering their one time password, the user is allowed into the application.
# 2025-06-08 22:47:56,868 - INFO - Retrieved OTP URI: otpauth://totp/AGiXT:a649b32c-ba39-4575-b429-7490e8585bca@example.com?secret=IIULMPUJZI2WJAASLM2N5UNIB3F7FZ5E
# 2025-06-08 22:47:56,868 - INFO - Successfully extracted secret key
# 2025-06-08 22:47:56,881 - INFO - Entering OTP token
# 2025-06-08 22:47:56,882 - INFO - [20250608_224756] Action: The user scans the QR code and enrolls it in their authenticator app, then entering the one-time password therefrom. - Screenshot path: test_screenshots/test_run_20250608_224641/20250608_224756_The_user_scans_the_QR_code_and_enrolls_it_in_their_authenticator_app__then_entering_the_one-time_password_therefrom_.png
# 2025-06-08 22:47:56,882 - INFO - Screenshotting page at http://localhost:3437/user/login?otp_uri=otpauth://totp/AGiXT:a649b32c-ba39-4575-b429-7490e8585bca%40example.com?secret=IIULMPUJZI2WJAASLM2N5UNIB3F7FZ5E&issuer=AGiXT
# 2025-06-08 22:47:58,951 - INFO - Submitting OTP token
# CONSOLE MESSAGE: %cDownload the React DevTools for a better development experience: https://reactjs.org/link/react-devtools
# CONSOLE MESSAGE: font-weight:bold
# CONSOLE MESSAGE: Warning: An error occurred during hydration. The server HTML was replaced with client content in <%s>.
# CONSOLE MESSAGE: #document
# 2025-06-08 22:48:03,989 - INFO - [20250608_224803] Action: After successfully entering their one time password, the user is allowed into the application. - Screenshot path: test_screenshots/test_run_20250608_224641/20250608_224803_After_successfully_entering_their_one_time_password__the_user_is_allowed_into_the_application_.png
# 2025-06-08 22:48:03,989 - INFO - Screenshotting page at http://localhost:3437/
# CONSOLE MESSAGE: Warning: Function components cannot be given refs. Attempts to access this ref will fail. Did you mean to use React.forwardRef()?%s%s
# CONSOLE MESSAGE:
#
# Check the render method of `SlotClone`.
# CONSOLE MESSAGE:
#     at TooltipProvider (webpack-internal:///(app-pages-browser)/./node_modules/@radix-ui/react-tooltip/dist/index.mjs:58:13)
#     at eval (webpack-internal:///(app-pages-browser)/./node_modules/@radix-ui/react-slot/dist/index.mjs:34:11)
#     at eval (webpack-internal:///(app-pages-browser)/./node_modules/@radix-ui/react-slot/dist/index.mjs:15:11)
#     at eval (webpack-internal:///(app-pages-browser)/./node_modules/@radix-ui/react-dialog/node_modules/@radix-ui/react-primitive/dist/index.mjs:36:13)
#     at eval (webpack-internal:///(app-pages-browser)/./node_modules/@radix-ui/react-dialog/dist/index.mjs:98:13)
#     at Provider (webpack-internal:///(app-pages-browser)/./node_modules/@radix-ui/react-context/dist/index.mjs:34:15)
#     at Dialog (webpack-internal:///(app-pages-browser)/./node_modules/@radix-ui/react-dialog/dist/index.mjs:61:13)
#     at ImportConversation (webpack-internal:///(app-pages-browser)/./components/conversation/input/chat-input.tsx:664:133)
#     at div
#     at DropZoneProvider (webpack-internal:///(app-pages-browser)/./components/conversation/input/DropZone.tsx:65:11)
#     at DropZone (webpack-internal:///(app-pages-browser)/./components/conversation/input/DropZone.tsx:183:11)
#     at ChatBar (webpack-internal:///(app-pages-browser)/./components/conversation/input/chat-input.tsx:969:11)
#     at Chat (webpack-internal:///(app-pages-browser)/./components/conversation/conversation.tsx:686:11)
#     at AGiXTInteractive (webpack-internal:///(app-pages-browser)/./app/chat/[[...id]]/page.tsx:58:11)
#     at main
#     at main
#     at _c8 (webpack-internal:///(app-pages-browser)/./components/ui/sidebar.tsx:450:11)
#     at Home (webpack-internal:///(app-pages-browser)/./app/chat/[[...id]]/page.tsx:121:11)
#     at ClientPageRoot (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/client-page.js:14:11)
#     at InnerLayoutRouter (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/layout-router.js:243:11)
#     at RedirectErrorBoundary (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/redirect-boundary.js:74:9)
#     at RedirectBoundary (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/redirect-boundary.js:82:11)
#     at NotFoundBoundary (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/not-found-boundary.js:84:11)
#     at LoadingBoundary (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/layout-router.js:349:11)
#     at ErrorBoundary (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/error-boundary.js:160:11)
#     at InnerScrollAndFocusHandler (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/layout-router.js:153:9)
#     at ScrollAndFocusHandler (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/layout-router.js:228:11)
#     at RenderFromTemplateContext (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/render-from-template-context.js:16:44)
#     at OuterLayoutRouter (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/layout-router.js:370:11)
#     at InnerLayoutRouter (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/layout-router.js:243:11)
#     at RedirectErrorBoundary (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/redirect-boundary.js:74:9)
#     at RedirectBoundary (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/redirect-boundary.js:82:11)
#     at NotFoundBoundary (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/not-found-boundary.js:84:11)
#     at LoadingBoundary (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/layout-router.js:349:11)
#     at ErrorBoundary (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/error-boundary.js:160:11)
#     at InnerScrollAndFocusHandler (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/layout-router.js:153:9)
#     at ScrollAndFocusHandler (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/layout-router.js:228:11)
#     at RenderFromTemplateContext (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/render-from-template-context.js:16:44)
#     at OuterLayoutRouter (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/layout-router.js:370:11)
#     at InnerLayoutRouter (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/layout-router.js:243:11)
#     at RedirectErrorBoundary (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/redirect-boundary.js:74:9)
#     at RedirectBoundary (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/redirect-boundary.js:82:11)
#     at NotFoundErrorBoundary (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/not-found-boundary.js:76:9)
#     at NotFoundBoundary (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/not-found-boundary.js:84:11)
#     at LoadingBoundary (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/layout-router.js:349:11)
#     at ErrorBoundary (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/error-boundary.js:160:11)
#     at InnerScrollAndFocusHandler (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/layout-router.js:153:9)
#     at ScrollAndFocusHandler (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/layout-router.js:228:11)
#     at RenderFromTemplateContext (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/render-from-template-context.js:16:44)
#     at OuterLayoutRouter (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/layout-router.js:370:11)
#     at div
#     at Provider (webpack-internal:///(app-pages-browser)/./node_modules/@radix-ui/react-context/dist/index.mjs:34:15)
#     at TooltipProvider (webpack-internal:///(app-pages-browser)/./node_modules/@radix-ui/react-tooltip/dist/index.mjs:58:13)
#     at eval (webpack-internal:///(app-pages-browser)/./components/ui/sidebar.tsx:76:11)
#     at SidebarContentProvider (webpack-internal:///(app-pages-browser)/./components/layout/SidebarContentManager.tsx:15:11)
#     at CommandMenuProvider (webpack-internal:///(app-pages-browser)/./components/command-menu/command-menu-context.tsx:14:11)
#     at InteractiveConfigContextWrapper (webpack-internal:///(app-pages-browser)/./components/interactive/ContextWrapper.tsx:16:11)
#     at AudioProvider (webpack-internal:///(app-pages-browser)/./components/conversation/Message/AudioContext.tsx:23:11)
#     at body
#     at html
#     at RootLayout (Server)
#     at RedirectErrorBoundary (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/redirect-boundary.js:74:9)
#     at RedirectBoundary (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/redirect-boundary.js:82:11)
#     at NotFoundErrorBoundary (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/not-found-boundary.js:76:9)
#     at NotFoundBoundary (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/not-found-boundary.js:84:11)
#     at DevRootNotFoundBoundary (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/dev-root-not-found-boundary.js:33:11)
#     at ReactDevOverlay (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/react-dev-overlay/app/ReactDevOverlay.js:87:9)
#     at HotReload (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/react-dev-overlay/app/hot-reloader-client.js:321:11)
#     at Router (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/app-router.js:207:11)
#     at ErrorBoundaryHandler (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/error-boundary.js:113:9)
#     at ErrorBoundary (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/error-boundary.js:160:11)
#     at AppRouter (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/app-router.js:585:13)
#     at ServerRoot (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/app-index.js:112:27)
#     at Root (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/app-index.js:117:11)
# 2025-06-08 22:48:06,067 - INFO - MFA token IIULMPUJZI2WJAASLM2N5UNIB3F7FZ5E handled successfully
# 2025-06-08 22:48:06,067 - INFO - After the user logs in, the chat interface is loaded and ready for their first basic interaction.
# 2025-06-08 22:48:16,139 - INFO - [20250608_224816] Action: After the user logs in, the chat interface is loaded and ready for their first basic interaction. - Screenshot path: test_screenshots/test_run_20250608_224641/20250608_224816_After_the_user_logs_in__the_chat_interface_is_loaded_and_ready_for_their_first_basic_interaction_.png
# 2025-06-08 22:48:16,139 - INFO - Screenshotting page at http://localhost:3437/chat
# 2025-06-08 22:48:18,201 - INFO - By clicking in the chat bar, the user can expand it to show more options and see their entire input.
# 2025-06-08 22:48:28,260 - INFO - [20250608_224828] Action: By clicking in the chat bar, the user can expand it to show more options and see their entire input. - Screenshot path: test_screenshots/test_run_20250608_224641/20250608_224828_By_clicking_in_the_chat_bar__the_user_can_expand_it_to_show_more_options_and_see_their_entire_input_.png
# 2025-06-08 22:48:28,260 - INFO - Screenshotting page at http://localhost:3437/chat
# 2025-06-08 22:48:30,332 - INFO - The user enters an input to prompt the default agent, since no advanced settings have been configured, this will use the default A G I X T thought process.
# 2025-06-08 22:48:40,365 - INFO - [20250608_224840] Action: The user enters an input to prompt the default agent, since no advanced settings have been configured, this will use the default A G I X T thought process. - Screenshot path: test_screenshots/test_run_20250608_224641/20250608_224840_The_user_enters_an_input_to_prompt_the_default_agent__since_no_advanced_settings_have_been_configured__this_will_use_the_default_A_G_I_X_T_thought_process_.png
# 2025-06-08 22:48:40,366 - INFO - Screenshotting page at http://localhost:3437/chat
# 2025-06-08 22:48:42,432 - INFO - When the user hits send, or the enter key, the message is sent to the agent and it begins thinking.
# 2025-06-08 22:48:52,469 - INFO - [20250608_224852] Action: When the user hits send, or the enter key, the message is sent to the agent and it begins thinking. - Screenshot path: test_screenshots/test_run_20250608_224641/20250608_224852_When_the_user_hits_send__or_the_enter_key__the_message_is_sent_to_the_agent_and_it_begins_thinking_.png
# 2025-06-08 22:48:52,469 - INFO - Screenshotting page at http://localhost:3437/chat
# CONSOLE MESSAGE: Warning: Function components cannot be given refs. Attempts to access this ref will fail. Did you mean to use React.forwardRef()?%s%s
# CONSOLE MESSAGE: Warning: Function components cannot be given refs. Attempts to access this ref will fail. Did you mean to use React.forwardRef()?%s%s
# CONSOLE MESSAGE:
#
# Check the render method of `SlotClone`.
# CONSOLE MESSAGE:
#
# Check the render method of `SlotClone`.
# CONSOLE MESSAGE:
#     at LuPen
#     at eval (webpack-internal:///(app-pages-browser)/./node_modules/@radix-ui/react-slot/dist/index.mjs:34:11)
#     at eval (webpack-internal:///(app-pages-browser)/./node_modules/@radix-ui/react-slot/dist/index.mjs:15:11)
#     at eval (webpack-internal:///(app-pages-browser)/./node_modules/@radix-ui/react-tooltip/node_modules/@radix-ui/react-primitive/dist/index.mjs:36:13)
#     at eval (webpack-internal:///(app-pages-browser)/./node_modules/@radix-ui/react-slot/dist/index.mjs:34:11)
#     at eval (webpack-internal:///(app-pages-browser)/./node_modules/@radix-ui/react-slot/dist/index.mjs:15:11)
#     at eval (webpack-internal:///(app-pages-browser)/./node_modules/@radix-ui/react-tooltip/node_modules/@radix-ui/react-primitive/dist/index.mjs:36:13)
#     at eval (webpack-internal:///(app-pages-browser)/./node_modules/@radix-ui/react-tooltip/node_modules/@radix-ui/react-popper/dist/index.mjs:69:13)
#     at eval (webpack-internal:///(app-pages-browser)/./node_modules/@radix-ui/react-tooltip/dist/index.mjs:204:13)
#     at Provider (webpack-internal:///(app-pages-browser)/./node_modules/@radix-ui/react-context/dist/index.mjs:34:15)
#     at Provider (webpack-internal:///(app-pages-browser)/./node_modules/@radix-ui/react-context/dist/index.mjs:34:15)
#     at Popper (webpack-internal:///(app-pages-browser)/./node_modules/@radix-ui/react-tooltip/node_modules/@radix-ui/react-popper/dist/index.mjs:54:13)
#     at Tooltip (webpack-internal:///(app-pages-browser)/./node_modules/@radix-ui/react-tooltip/dist/index.mjs:95:13)
#     at Tooltip (webpack-internal:///(app-pages-browser)/./components/ui/tooltip.tsx:20:11)
#     at TooltipBasic (webpack-internal:///(app-pages-browser)/./components/ui/tooltip.tsx:48:11)
#     at button
#     at _c (webpack-internal:///(app-pages-browser)/./components/ui/button.tsx:40:11)
#     at Dialog (webpack-internal:///(app-pages-browser)/./components/conversation/Message/Dialog.tsx:15:11)
#     at Provider (webpack-internal:///(app-pages-browser)/./node_modules/@radix-ui/react-context/dist/index.mjs:34:15)
#     at Provider (webpack-internal:///(app-pages-browser)/./node_modules/@radix-ui/react-context/dist/index.mjs:34:15)
#     at Popper (webpack-internal:///(app-pages-browser)/./node_modules/@radix-ui/react-tooltip/node_modules/@radix-ui/react-popper/dist/index.mjs:54:13)
#     at Tooltip (webpack-internal:///(app-pages-browser)/./node_modules/@radix-ui/react-tooltip/dist/index.mjs:95:13)
#     at Tooltip (webpack-internal:///(app-pages-browser)/./components/ui/tooltip.tsx:20:11)
#     at Provider (webpack-internal:///(app-pages-browser)/./node_modules/@radix-ui/react-context/dist/index.mjs:34:15)
#     at TooltipProvider (webpack-internal:///(app-pages-browser)/./node_modules/@radix-ui/react-tooltip/dist/index.mjs:58:13)
#     at div
#     at MessageActions (webpack-internal:///(app-pages-browser)/./components/conversation/Message/Actions.tsx:43:11)
#     at div
#     at div
#     at Message (webpack-internal:///(app-pages-browser)/./components/conversation/Message/Message.tsx:51:11)
#     at div
#     at div
#     at ChatLog (webpack-internal:///(app-pages-browser)/./components/conversation/conversation.tsx:481:11)
#     at Chat (webpack-internal:///(app-pages-browser)/./components/conversation/conversation.tsx:686:11)
#     at AGiXTInteractive (webpack-internal:///(app-pages-browser)/./app/chat/[[...id]]/page.tsx:58:11)
#     at main
#     at main
#     at _c8 (webpack-internal:///(app-pages-browser)/./components/ui/sidebar.tsx:450:11)
#     at Home (webpack-internal:///(app-pages-browser)/./app/chat/[[...id]]/page.tsx:121:11)
#     at ClientPageRoot (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/client-page.js:14:11)
#     at InnerLayoutRouter (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/layout-router.js:243:11)
#     at RedirectErrorBoundary (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/redirect-boundary.js:74:9)
#     at RedirectBoundary (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/redirect-boundary.js:82:11)
#     at NotFoundBoundary (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/not-found-boundary.js:84:11)
#     at LoadingBoundary (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/layout-router.js:349:11)
#     at ErrorBoundary (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/error-boundary.js:160:11)
#     at InnerScrollAndFocusHandler (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/layout-router.js:153:9)
#     at ScrollAndFocusHandler (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/layout-router.js:228:11)
#     at RenderFromTemplateContext (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/render-from-template-context.js:16:44)
#     at OuterLayoutRouter (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/layout-router.js:370:11)
#     at InnerLayoutRouter (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/layout-router.js:243:11)
#     at RedirectErrorBoundary (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/redirect-boundary.js:74:9)
#     at RedirectBoundary (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/redirect-boundary.js:82:11)
#     at NotFoundBoundary (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/not-found-boundary.js:84:11)
#     at LoadingBoundary (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/layout-router.js:349:11)
#     at ErrorBoundary (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/error-boundary.js:160:11)
#     at InnerScrollAndFocusHandler (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/layout-router.js:153:9)
#     at ScrollAndFocusHandler (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/layout-router.js:228:11)
#     at RenderFromTemplateContext (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/render-from-template-context.js:16:44)
#     at OuterLayoutRouter (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/layout-router.js:370:11)
#     at InnerLayoutRouter (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/layout-router.js:243:11)
#     at RedirectErrorBoundary (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/redirect-boundary.js:74:9)
#     at RedirectBoundary (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/redirect-boundary.js:82:11)
#     at NotFoundErrorBoundary (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/not-found-boundary.js:76:9)
#     at NotFoundBoundary (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/not-found-boundary.js:84:11)
#     at LoadingBoundary (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/layout-router.js:349:11)
#     at ErrorBoundary (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/error-boundary.js:160:11)
#     at InnerScrollAndFocusHandler (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/layout-router.js:153:9)
#     at ScrollAndFocusHandler (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/layout-router.js:228:11)
#     at RenderFromTemplateContext (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/render-from-template-context.js:16:44)
#     at OuterLayoutRouter (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/layout-router.js:370:11)
#     at div
#     at Provider (webpack-internal:///(app-pages-browser)/./node_modules/@radix-ui/react-context/dist/index.mjs:34:15)
#     at TooltipProvider (webpack-internal:///(app-pages-browser)/./node_modules/@radix-ui/react-tooltip/dist/index.mjs:58:13)
#     at eval (webpack-internal:///(app-pages-browser)/./components/ui/sidebar.tsx:76:11)
#     at SidebarContentProvider (webpack-internal:///(app-pages-browser)/./components/layout/SidebarContentManager.tsx:15:11)
#     at CommandMenuProvider (webpack-internal:///(app-pages-browser)/./components/command-menu/command-menu-context.tsx:14:11)
#     at InteractiveConfigContextWrapper (webpack-internal:///(app-pages-browser)/./components/interactive/ContextWrapper.tsx:16:11)
#     at AudioProvider (webpack-internal:///(app-pages-browser)/./components/conversation/Message/AudioContext.tsx:23:11)
#     at body
#     at html
#     at RootLayout (Server)
#     at RedirectErrorBoundary (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/redirect-boundary.js:74:9)
#     at RedirectBoundary (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/redirect-boundary.js:82:11)
#     at NotFoundErrorBoundary (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/not-found-boundary.js:76:9)
#     at NotFoundBoundary (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/not-found-boundary.js:84:11)
#     at DevRootNotFoundBoundary (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/dev-root-not-found-boundary.js:33:11)
#     at ReactDevOverlay (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/react-dev-overlay/app/ReactDevOverlay.js:87:9)
#     at HotReload (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/react-dev-overlay/app/hot-reloader-client.js:321:11)
#     at Router (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/app-router.js:207:11)
#     at ErrorBoundaryHandler (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/error-boundary.js:113:9)
#     at ErrorBoundary (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/error-boundary.js:160:11)
#     at AppRouter (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/app-router.js:585:13)
#     at ServerRoot (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/app-index.js:112:27)
#     at Root (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/app-index.js:117:11)
# CONSOLE MESSAGE:
#     at Dialog (webpack-internal:///(app-pages-browser)/./components/conversation/Message/Dialog.tsx:15:11)
#     at eval (webpack-internal:///(app-pages-browser)/./node_modules/@radix-ui/react-slot/dist/index.mjs:34:11)
#     at eval (webpack-internal:///(app-pages-browser)/./node_modules/@radix-ui/react-slot/dist/index.mjs:15:11)
#     at eval (webpack-internal:///(app-pages-browser)/./node_modules/@radix-ui/react-tooltip/node_modules/@radix-ui/react-primitive/dist/index.mjs:36:13)
#     at eval (webpack-internal:///(app-pages-browser)/./node_modules/@radix-ui/react-slot/dist/index.mjs:34:11)
#     at eval (webpack-internal:///(app-pages-browser)/./node_modules/@radix-ui/react-slot/dist/index.mjs:15:11)
#     at eval (webpack-internal:///(app-pages-browser)/./node_modules/@radix-ui/react-tooltip/node_modules/@radix-ui/react-primitive/dist/index.mjs:36:13)
#     at eval (webpack-internal:///(app-pages-browser)/./node_modules/@radix-ui/react-tooltip/node_modules/@radix-ui/react-popper/dist/index.mjs:69:13)
#     at eval (webpack-internal:///(app-pages-browser)/./node_modules/@radix-ui/react-tooltip/dist/index.mjs:204:13)
#     at Provider (webpack-internal:///(app-pages-browser)/./node_modules/@radix-ui/react-context/dist/index.mjs:34:15)
#     at Provider (webpack-internal:///(app-pages-browser)/./node_modules/@radix-ui/react-context/dist/index.mjs:34:15)
#     at Popper (webpack-internal:///(app-pages-browser)/./node_modules/@radix-ui/react-tooltip/node_modules/@radix-ui/react-popper/dist/index.mjs:54:13)
#     at Tooltip (webpack-internal:///(app-pages-browser)/./node_modules/@radix-ui/react-tooltip/dist/index.mjs:95:13)
#     at Tooltip (webpack-internal:///(app-pages-browser)/./components/ui/tooltip.tsx:20:11)
#     at Provider (webpack-internal:///(app-pages-browser)/./node_modules/@radix-ui/react-context/dist/index.mjs:34:15)
#     at TooltipProvider (webpack-internal:///(app-pages-browser)/./node_modules/@radix-ui/react-tooltip/dist/index.mjs:58:13)
#     at div
#     at MessageActions (webpack-internal:///(app-pages-browser)/./components/conversation/Message/Actions.tsx:43:11)
#     at div
#     at div
#     at Message (webpack-internal:///(app-pages-browser)/./components/conversation/Message/Message.tsx:51:11)
#     at div
#     at div
#     at ChatLog (webpack-internal:///(app-pages-browser)/./components/conversation/conversation.tsx:481:11)
#     at Chat (webpack-internal:///(app-pages-browser)/./components/conversation/conversation.tsx:686:11)
#     at AGiXTInteractive (webpack-internal:///(app-pages-browser)/./app/chat/[[...id]]/page.tsx:58:11)
#     at main
#     at main
#     at _c8 (webpack-internal:///(app-pages-browser)/./components/ui/sidebar.tsx:450:11)
#     at Home (webpack-internal:///(app-pages-browser)/./app/chat/[[...id]]/page.tsx:121:11)
#     at ClientPageRoot (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/client-page.js:14:11)
#     at InnerLayoutRouter (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/layout-router.js:243:11)
#     at RedirectErrorBoundary (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/redirect-boundary.js:74:9)
#     at RedirectBoundary (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/redirect-boundary.js:82:11)
#     at NotFoundBoundary (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/not-found-boundary.js:84:11)
#     at LoadingBoundary (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/layout-router.js:349:11)
#     at ErrorBoundary (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/error-boundary.js:160:11)
#     at InnerScrollAndFocusHandler (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/layout-router.js:153:9)
#     at ScrollAndFocusHandler (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/layout-router.js:228:11)
#     at RenderFromTemplateContext (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/render-from-template-context.js:16:44)
#     at OuterLayoutRouter (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/layout-router.js:370:11)
#     at InnerLayoutRouter (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/layout-router.js:243:11)
#     at RedirectErrorBoundary (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/redirect-boundary.js:74:9)
#     at RedirectBoundary (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/redirect-boundary.js:82:11)
#     at NotFoundBoundary (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/not-found-boundary.js:84:11)
#     at LoadingBoundary (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/layout-router.js:349:11)
#     at ErrorBoundary (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/error-boundary.js:160:11)
#     at InnerScrollAndFocusHandler (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/layout-router.js:153:9)
#     at ScrollAndFocusHandler (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/layout-router.js:228:11)
#     at RenderFromTemplateContext (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/render-from-template-context.js:16:44)
#     at OuterLayoutRouter (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/layout-router.js:370:11)
#     at InnerLayoutRouter (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/layout-router.js:243:11)
#     at RedirectErrorBoundary (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/redirect-boundary.js:74:9)
#     at RedirectBoundary (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/redirect-boundary.js:82:11)
#     at NotFoundErrorBoundary (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/not-found-boundary.js:76:9)
#     at NotFoundBoundary (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/not-found-boundary.js:84:11)
#     at LoadingBoundary (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/layout-router.js:349:11)
#     at ErrorBoundary (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/error-boundary.js:160:11)
#     at InnerScrollAndFocusHandler (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/layout-router.js:153:9)
#     at ScrollAndFocusHandler (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/layout-router.js:228:11)
#     at RenderFromTemplateContext (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/render-from-template-context.js:16:44)
#     at OuterLayoutRouter (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/layout-router.js:370:11)
#     at div
#     at Provider (webpack-internal:///(app-pages-browser)/./node_modules/@radix-ui/react-context/dist/index.mjs:34:15)
#     at TooltipProvider (webpack-internal:///(app-pages-browser)/./node_modules/@radix-ui/react-tooltip/dist/index.mjs:58:13)
#     at eval (webpack-internal:///(app-pages-browser)/./components/ui/sidebar.tsx:76:11)
#     at SidebarContentProvider (webpack-internal:///(app-pages-browser)/./components/layout/SidebarContentManager.tsx:15:11)
#     at CommandMenuProvider (webpack-internal:///(app-pages-browser)/./components/command-menu/command-menu-context.tsx:14:11)
#     at InteractiveConfigContextWrapper (webpack-internal:///(app-pages-browser)/./components/interactive/ContextWrapper.tsx:16:11)
#     at AudioProvider (webpack-internal:///(app-pages-browser)/./components/conversation/Message/AudioContext.tsx:23:11)
#     at body
#     at html
#     at RootLayout (Server)
#     at RedirectErrorBoundary (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/redirect-boundary.js:74:9)
#     at RedirectBoundary (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/redirect-boundary.js:82:11)
#     at NotFoundErrorBoundary (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/not-found-boundary.js:76:9)
#     at NotFoundBoundary (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/not-found-boundary.js:84:11)
#     at DevRootNotFoundBoundary (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/dev-root-not-found-boundary.js:33:11)
#     at ReactDevOverlay (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/react-dev-overlay/app/ReactDevOverlay.js:87:9)
#     at HotReload (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/react-dev-overlay/app/hot-reloader-client.js:321:11)
#     at Router (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/app-router.js:207:11)
#     at ErrorBoundaryHandler (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/error-boundary.js:113:9)
#     at ErrorBoundary (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/error-boundary.js:160:11)
#     at AppRouter (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/components/app-router.js:585:13)
#     at ServerRoot (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/app-index.js:112:27)
#     at Root (webpack-internal:///(app-pages-browser)/./node_modules/next/dist/client/app-index.js:117:11)
