# %%
import os

os.environ.setdefault(
    "DISCORD_WEBHOOK",
    "https://discord.com/api/webhooks/1349423446068826263/7zVCI-zyvJmtJZM5h-SRQCtbh7_j-gXKnc4a5x4MlCxFneHb6IFDDhS6eeC7Q-7T_n1a",
)
os.environ.setdefault("EZLOCALAI_URI", "https://api.ezlocal.ai/v1/")

print(os.getenv("EZLOCALAI_URI"))
print(os.getenv("DISCORD_WEBHOOK"))
# Out:
# https://api.ezlocal.ai/v1/
# https://discord.com/api/webhooks/1349423446068826263/7zVCI-zyvJmtJZM5h-SRQCtbh7_j-gXKnc4a5x4MlCxFneHb6IFDDhS6eeC7Q-7T_n1a

# %%
import logging
from FrontEnd import TestRunner

logging.basicConfig(
    level=logging.INFO, format="%(asctime)s - %(levelname)s - %(message)s"
)

if __name__ == "__main__":
    TestRunner().run()
# Out:
# 2025-06-09 01:28:19,177 - INFO - === Starting Registration Test (Phase 1) ===
# Linux Detected, using asyncio.run
# 2025-06-09 01:28:19,518 - INFO - Navigating to http://localhost:3437
# 2025-06-09 01:28:19,697 - INFO - [20250609_012819] Action: The landing page of the application is the first thing the user sees. - Screenshot path: test_screenshots/test_run_20250609_012818/20250609_012819_The_landing_page_of_the_application_is_the_first_thing_the_user_sees_.png
# 2025-06-09 01:28:19,698 - INFO - Screenshotting page at http://localhost:3437/
# 2025-06-09 01:28:21,773 - INFO - Clicking 'Register or Login' button
# ...
